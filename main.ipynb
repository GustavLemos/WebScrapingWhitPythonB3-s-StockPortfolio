# %%
import pandas as pd
pd.set_option('display.min_rows', 50)
pd.set_option('display.max_rows', 200)

# %%
def busca_carteira_teorica(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1]

# %%
ibov = busca_carteira_teorica('ibov')
ibov.sort_values('Part. (%)', ascending=False)
# Out:
#                 Ação       Tipo Qtde. Teórica  Part. (%)
# Código
# VALE3           VALE      ON NM    2837320141     13.770
# ITUB4   ITAUUNIBANCO  PN EDJ N1    4757466114      5.802
# B3SA3             B3      ON NM    1930877944      5.167
# PETR4      PETROBRAS      PN N2    4566457037      4.946
# BBDC4       BRADESCO   PN EJ N1    4261649634      4.663
# PETR3      PETROBRAS      ON N2    3307982840      3.585
# MGLU3    MAGAZ LUIZA      ON NM    2668955512      3.226
# ABEV3      AMBEV S/A         ON    4355174839      2.953
# WEGE3            WEG   ON ED NM     741148001      2.847
# SUZB3    SUZANO S.A.      ON NM     724921241      2.659
# GNDI3    INTERMEDICA      ON NM     588176771      2.597
# ITSA4         ITAUSA   PN ED N1    4515538171      2.139
# JBSS3            JBS      ON NM    1500315048      1.982
# NTCO3   GRUPO NATURA      ON NM     841083922      1.919
# BBAS3         BRASIL  ON ERJ NM    1283197221      1.760
# RENT3       LOCALIZA      ON NM     592069308      1.725
# LREN3   LOJAS RENNER      ON NM     785417914      1.437
# BPAC11    BTGP BANCO     UNT N2     263871572      1.319
# GGBR4         GERDAU      PN N1     995903643      1.308
# RADL3   RAIADROGASIL      ON NM    1072645150      1.203
# KLBN11    KLABIN S/A     UNT N2     788757519      1.195
# BRDT3   PETROBRAS BR      ON NM    1164958126      1.129
# BBDC3       BRADESCO   ON EJ N1    1147260246      1.125
# RAIL3      RUMO S.A.      ON NM    1218081171      1.084
# CSNA3   SID NACIONAL         ON     642398790      1.075
# LAME4   LOJAS AMERIC      PN N1     843325974      1.025
# UGPA3       ULTRAPAR      ON NM    1087056490      1.004
# EQTL3     EQUATORIAL      ON NM    1010286085      0.988
# VVAR3      VIAVAREJO      ON NM    1595083594      0.951
# ENEV3          ENEVA      ON NM     287844670      0.948
# VIVT3   TELEF BRASIL      ON EJ     444219852      0.947
# HAPV3        HAPVIDA      ON NM    1085256490      0.872
# BRFS3         BRF SA      ON NM     811759800      0.867
# BBSE3   BBSEGURIDADE      ON NM     671584841      0.820
# BTOW3    B2W DIGITAL      ON NM     201549295      0.801
# TOTS3          TOTVS      ON NM     480228410      0.744
# PRIO3       PETRORIO      ON NM     164860900      0.716
# BRAP4      BRADESPAR      PN N1     222075664      0.706
# SANB11  SANTANDER BR        UNT     355666691      0.647
# AZUL4           AZUL      PN N2     327283207      0.645
# HYPE3         HYPERA      ON NM     410147968      0.635
# CCRO3         CCR SA      ON NM    1115695556      0.600
# SBSP3         SABESP      ON NM     339999111      0.593
# ELET3     ELETROBRAS      ON N1     358018408      0.556
# ASAI3          ASSAI      ON NM     157635935      0.554
# CMIG4          CEMIG      PN N1     969723092      0.551
# ENGI11      ENERGISA     UNT N2     250679709      0.527
# CSAN3          COSAN      ON NM     129314042      0.525
# TIMS3            TIM      ON NM     808485985      0.506
# EGIE3   ENGIE BRASIL      ON NM     254792279      0.504
# SULA11   SUL AMERICA     UNT N2     279572852      0.451
# QUAL3      QUALICORP      ON NM     283467789      0.444
# EMBR3        EMBRAER      ON NM     736143105      0.443
# USIM5       USIMINAS     PNA N1     513729947      0.426
# YDUQ3     YDUQS PART      ON NM     300483575      0.426
# BRKM5        BRASKEM     PNA N1     264640575      0.414
# GOAU4     GERDAU MET      PN N1     693699918      0.407
# FLRY3         FLEURY      ON NM     303800430      0.388
# LCAM3     LOCAMERICA      ON NM     323763077      0.386
# ELET6     ELETROBRAS     PNB N1     242977127      0.383
# CPLE6          COPEL     PNB N1     128297543      0.373
# CRFB3   CARREFOUR BR      ON NM     391758726      0.368
# IRBR3   IRBBRASIL RE      ON NM    1255327516      0.360
# BRML3   BR MALLS PAR      ON NM     843728684      0.339
# CYRE3   CYRELA REALT      ON NM     281154098      0.339
# COGN3       COGNA ON      ON NM    1847994874      0.328
# TAEE11         TAESA     UNT N2     218568274      0.325
# MULT3      MULTIPLAN      ON N2     276848567      0.264
# MRFG3        MARFRIG      ON NM     368864634      0.260
# CPFE3   CPFL ENERGIA      ON NM     187714249      0.259
# MRVE3            MRV      ON NM     298796441      0.243
# ENBR3    ENERGIAS BR      ON NM     250403441      0.217
# CIEL3          CIELO      ON NM    1112196638      0.185
# PCAR3   P.ACUCAR-CBD   ON EC NM     157635935      0.181
# EZTC3          EZTEC      ON NM      95756217      0.146
# GOLL4            GOL      PN N2     137725788      0.145
# CVCB3     CVC BRASIL      ON NM     172756818      0.136
# IGTA3       IGUATEMI      ON NM      85796919      0.129
# BEEF3        MINERVA      ON NM     239331676      0.114
# JHSF3      JHSF PART      ON NM     288952690      0.093
# HGTX3     CIA HERING      ON NM     126186408      0.091
# ECOR3    ECORODOVIAS      ON NM     171109276      0.090

# %%
smll = busca_carteira_teorica('smll')

# %%
ibrx = busca_carteira_teorica('ibrx')

# %%
pd.concat([ibov, ibrx], keys=['IBOV', 'IBRX'], axis=1)
# Out:
#                 IBOV                                             IBRX  \
#                 Ação       Tipo Qtde. Teórica Part. (%)          Ação
# Código
# ABEV3      AMBEV S/A         ON    4355174839     2.953     AMBEV S/A
# ASAI3          ASSAI      ON NM     157635935     0.554         ASSAI
# AZUL4           AZUL      PN N2     327283207     0.645          AZUL
# B3SA3             B3      ON NM    1930877944     5.167            B3
# BBAS3         BRASIL  ON ERJ NM    1283197221     1.760        BRASIL
# BBDC3       BRADESCO   ON EJ N1    1147260246     1.125      BRADESCO
# BBDC4       BRADESCO   PN EJ N1    4261649634     4.663      BRADESCO
# BBSE3   BBSEGURIDADE      ON NM     671584841     0.820  BBSEGURIDADE
# BEEF3        MINERVA      ON NM     239331676     0.114       MINERVA
# BPAC11    BTGP BANCO     UNT N2     263871572     1.319    BTGP BANCO
# BRAP4      BRADESPAR      PN N1     222075664     0.706     BRADESPAR
# BRDT3   PETROBRAS BR      ON NM    1164958126     1.129  PETROBRAS BR
# BRFS3         BRF SA      ON NM     811759800     0.867        BRF SA
# BRKM5        BRASKEM     PNA N1     264640575     0.414       BRASKEM
# BRML3   BR MALLS PAR      ON NM     843728684     0.339  BR MALLS PAR
# BTOW3    B2W DIGITAL      ON NM     201549295     0.801   B2W DIGITAL
# CCRO3         CCR SA      ON NM    1115695556     0.600        CCR SA
# CIEL3          CIELO      ON NM    1112196638     0.185         CIELO
# CMIG4          CEMIG      PN N1     969723092     0.551         CEMIG
# COGN3       COGNA ON      ON NM    1847994874     0.328      COGNA ON
# CPFE3   CPFL ENERGIA      ON NM     187714249     0.259  CPFL ENERGIA
# CPLE6          COPEL     PNB N1     128297543     0.373         COPEL
# CRFB3   CARREFOUR BR      ON NM     391758726     0.368  CARREFOUR BR
# CSAN3          COSAN      ON NM     129314042     0.525         COSAN
# CSNA3   SID NACIONAL         ON     642398790     1.075  SID NACIONAL
# CVCB3     CVC BRASIL      ON NM     172756818     0.136    CVC BRASIL
# CYRE3   CYRELA REALT      ON NM     281154098     0.339  CYRELA REALT
# ECOR3    ECORODOVIAS      ON NM     171109276     0.090   ECORODOVIAS
# EGIE3   ENGIE BRASIL      ON NM     254792279     0.504  ENGIE BRASIL
# ELET3     ELETROBRAS      ON N1     358018408     0.556    ELETROBRAS
# ELET6     ELETROBRAS     PNB N1     242977127     0.383    ELETROBRAS
# EMBR3        EMBRAER      ON NM     736143105     0.443       EMBRAER
# ENBR3    ENERGIAS BR      ON NM     250403441     0.217   ENERGIAS BR
# ENEV3          ENEVA      ON NM     287844670     0.948         ENEVA
# ENGI11      ENERGISA     UNT N2     250679709     0.527      ENERGISA
# EQTL3     EQUATORIAL      ON NM    1010286085     0.988    EQUATORIAL
# EZTC3          EZTEC      ON NM      95756217     0.146         EZTEC
# FLRY3         FLEURY      ON NM     303800430     0.388        FLEURY
# GGBR4         GERDAU      PN N1     995903643     1.308        GERDAU
# GNDI3    INTERMEDICA      ON NM     588176771     2.597   INTERMEDICA
# GOAU4     GERDAU MET      PN N1     693699918     0.407    GERDAU MET
# GOLL4            GOL      PN N2     137725788     0.145           GOL
# HAPV3        HAPVIDA      ON NM    1085256490     0.872       HAPVIDA
# HGTX3     CIA HERING      ON NM     126186408     0.091    CIA HERING
# HYPE3         HYPERA      ON NM     410147968     0.635        HYPERA
# IGTA3       IGUATEMI      ON NM      85796919     0.129      IGUATEMI
# IRBR3   IRBBRASIL RE      ON NM    1255327516     0.360  IRBBRASIL RE
# ITSA4         ITAUSA   PN ED N1    4515538171     2.139        ITAUSA
# ITUB4   ITAUUNIBANCO  PN EDJ N1    4757466114     5.802  ITAUUNIBANCO
# JBSS3            JBS      ON NM    1500315048     1.982           JBS
# JHSF3      JHSF PART      ON NM     288952690     0.093     JHSF PART
# KLBN11    KLABIN S/A     UNT N2     788757519     1.195    KLABIN S/A
# LAME4   LOJAS AMERIC      PN N1     843325974     1.025  LOJAS AMERIC
# LCAM3     LOCAMERICA      ON NM     323763077     0.386    LOCAMERICA
# LREN3   LOJAS RENNER      ON NM     785417914     1.437  LOJAS RENNER
# MGLU3    MAGAZ LUIZA      ON NM    2668955512     3.226   MAGAZ LUIZA
# MRFG3        MARFRIG      ON NM     368864634     0.260       MARFRIG
# MRVE3            MRV      ON NM     298796441     0.243           MRV
# MULT3      MULTIPLAN      ON N2     276848567     0.264     MULTIPLAN
# NTCO3   GRUPO NATURA      ON NM     841083922     1.919  GRUPO NATURA
# PCAR3   P.ACUCAR-CBD   ON EC NM     157635935     0.181  P.ACUCAR-CBD
# PETR3      PETROBRAS      ON N2    3307982840     3.585     PETROBRAS
# PETR4      PETROBRAS      PN N2    4566457037     4.946     PETROBRAS
# PRIO3       PETRORIO      ON NM     164860900     0.716      PETRORIO
# QUAL3      QUALICORP      ON NM     283467789     0.444     QUALICORP
# RADL3   RAIADROGASIL      ON NM    1072645150     1.203  RAIADROGASIL
# RAIL3      RUMO S.A.      ON NM    1218081171     1.084     RUMO S.A.
# RENT3       LOCALIZA      ON NM     592069308     1.725      LOCALIZA
# SANB11  SANTANDER BR        UNT     355666691     0.647  SANTANDER BR
# SBSP3         SABESP      ON NM     339999111     0.593        SABESP
# SULA11   SUL AMERICA     UNT N2     279572852     0.451   SUL AMERICA
# SUZB3    SUZANO S.A.      ON NM     724921241     2.659   SUZANO S.A.
# TAEE11         TAESA     UNT N2     218568274     0.325         TAESA
# TIMS3            TIM      ON NM     808485985     0.506           TIM
# TOTS3          TOTVS      ON NM     480228410     0.744         TOTVS
# UGPA3       ULTRAPAR      ON NM    1087056490     1.004      ULTRAPAR
# USIM5       USIMINAS     PNA N1     513729947     0.426      USIMINAS
# VALE3           VALE      ON NM    2837320141    13.770          VALE
# VIVT3   TELEF BRASIL      ON EJ     444219852     0.947  TELEF BRASIL
# VVAR3      VIAVAREJO      ON NM    1595083594     0.951     VIAVAREJO
# WEGE3            WEG   ON ED NM     741148001     2.847           WEG
# YDUQ3     YDUQS PART      ON NM     300483575     0.426    YDUQS PART
# ALPA4            NaN        NaN           NaN       NaN    ALPARGATAS
# ALSO3            NaN        NaN           NaN       NaN  ALIANSCSONAE
# AMAR3            NaN        NaN           NaN       NaN  LOJAS MARISA
# CESP6            NaN        NaN           NaN       NaN          CESP
# CNTO3            NaN        NaN           NaN       NaN      CENTAURO
# CSMG3            NaN        NaN           NaN       NaN        COPASA
# DTEX3            NaN        NaN           NaN       NaN       DURATEX
# LAME3            NaN        NaN           NaN       NaN  LOJAS AMERIC
# LIGT3            NaN        NaN           NaN       NaN     LIGHT S/A
# LINX3            NaN        NaN           NaN       NaN          LINX
# LWSA3            NaN        NaN           NaN       NaN       LOCAWEB
# MDIA3            NaN        NaN           NaN       NaN  M.DIASBRANCO
# MEAL3            NaN        NaN           NaN       NaN       IMC S/A
# MOVI3            NaN        NaN           NaN       NaN        MOVIDA
# NEOE3            NaN        NaN           NaN       NaN    NEOENERGIA
# PSSA3            NaN        NaN           NaN       NaN  PORTO SEGURO
# RAPT4            NaN        NaN           NaN       NaN   RANDON PART
# SAPR11           NaN        NaN           NaN       NaN       SANEPAR
# TRPL4            NaN        NaN           NaN       NaN  TRAN PAULIST
#
#
#              Tipo Qtde. Teórica Part. (%)
# Código
# ABEV3          ON    4355174839     2.544
# ASAI3       ON NM     157635935     0.477
# AZUL4       PN N2     327283207     0.556
# B3SA3       ON NM    2043531244     4.711
# BBAS3   ON ERJ NM    1283197221     1.516
# BBDC3    ON EJ N1    1253093907     1.058
# BBDC4    PN EJ N1    4261649634     4.017
# BBSE3       ON NM     671584841     0.706
# BEEF3       ON NM     239331676     0.098
# BPAC11     UNT N2     263871572     1.136
# BRAP4       PN N1     222075664     0.608
# BRDT3       ON NM    1164958126     0.973
# BRFS3       ON NM     811759800     0.747
# BRKM5      PNA N1     264640575     0.357
# BRML3       ON NM     843728684     0.292
# BTOW3       ON NM     201549295     0.690
# CCRO3       ON NM    1115695556     0.517
# CIEL3       ON NM    1112196638     0.159
# CMIG4       PN N1     969723092     0.474
# COGN3       ON NM    1847994874     0.283
# CPFE3       ON NM     187714249     0.223
# CPLE6      PNB N1     128297543     0.321
# CRFB3       ON NM     391758726     0.317
# CSAN3       ON NM     129314042     0.452
# CSNA3          ON     642398790     0.926
# CVCB3       ON NM     172756818     0.117
# CYRE3       ON NM     281154098     0.292
# ECOR3       ON NM     171109276     0.077
# EGIE3       ON NM     254792279     0.434
# ELET3       ON N1     358018408     0.479
# ELET6      PNB N1     242977127     0.330
# EMBR3       ON NM     736143105     0.381
# ENBR3       ON NM     250403441     0.187
# ENEV3       ON NM     315480873     0.896
# ENGI11     UNT N2     250679709     0.454
# EQTL3       ON NM    1010286085     0.851
# EZTC3       ON NM      95756217     0.126
# FLRY3       ON NM     303800430     0.334
# GGBR4       PN N1     995903643     1.127
# GNDI3       ON NM     588176771     2.237
# GOAU4       PN N1     693699918     0.350
# GOLL4       PN N2     137725788     0.125
# HAPV3       ON NM    1085256490     0.751
# HGTX3       ON NM     126186408     0.079
# HYPE3       ON NM     410147968     0.547
# IGTA3       ON NM      85796919     0.112
# IRBR3       ON NM    1255327516     0.311
# ITSA4    PN ED N1    4515538171     1.842
# ITUB4   PN EDJ N1    4757466114     4.998
# JBSS3       ON NM    1500315048     1.707
# JHSF3       ON NM     288952690     0.080
# KLBN11     UNT N2     788757519     1.029
# LAME4       PN N1     843325974     0.883
# LCAM3       ON NM     323763077     0.332
# LREN3       ON NM     785417914     1.238
# MGLU3       ON NM    2668955512     2.779
# MRFG3       ON NM     368864634     0.224
# MRVE3       ON NM     298796441     0.209
# MULT3       ON N2     276848567     0.228
# NTCO3       ON NM     841083922     1.653
# PCAR3    ON EC NM     157635935     0.156
# PETR3       ON N2    3684060179     3.439
# PETR4       PN N2    4566457037     4.261
# PRIO3       ON NM     164860900     0.617
# QUAL3       ON NM     283467789     0.382
# RADL3       ON NM    1072645150     1.036
# RAIL3       ON NM    1218081171     0.934
# RENT3       ON NM     592069308     1.486
# SANB11        UNT     355666691     0.557
# SBSP3       ON NM     339999111     0.511
# SULA11     UNT N2     279572852     0.389
# SUZB3       ON NM     724921241     2.290
# TAEE11     UNT N2     218568274     0.280
# TIMS3       ON NM     808485985     0.436
# TOTS3       ON NM     480228410     0.641
# UGPA3       ON NM    1087056490     0.864
# USIM5      PNA N1     513729947     0.367
# VALE3       ON NM    5128642481    21.441
# VIVT3       ON EJ     444219852     0.816
# VVAR3       ON NM    1595083594     0.819
# WEGE3    ON ED NM     741148001     2.452
# YDUQ3       ON NM     300483575     0.367
# ALPA4       PN N1     168770200     0.253
# ALSO3       ON NM     127376805     0.123
# AMAR3       ON NM     111476495     0.024
# CESP6      PNB N1     182017689     0.204
# CNTO3       ON NM      88709474     0.084
# CSMG3       ON NM     188444559     0.111
# DTEX3       ON NM     273421574     0.213
# LAME3       ON N1     245640344     0.238
# LIGT3       ON NM     372555324     0.276
# LINX3       ON NM     147968946     0.243
# LWSA3       ON NM     423963160     0.524
# MDIA3       ON NM      83669782     0.102
# MEAL3       ON NM     265820032     0.033
# MOVI3       ON NM     132113940     0.097
# NEOE3       ON NM     226115915     0.150
# PSSA3       ON NM      93637072     0.171
# RAPT4       PN N1     177421406     0.095
# SAPR11     UNT N2     200991234     0.166
# TRPL4    PN ED N1     395797044     0.395
